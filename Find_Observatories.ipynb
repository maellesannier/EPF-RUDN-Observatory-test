# %%
#### GIS PROGRAMMING TO FIND A LOCATION FOR A NEW ASTRONOMICAL OBSERVATORY IN FRANCE ####
#### Sannier Maelle ####
#### 04.30.2020 ####
#### EPF Graduate School of Engineering, Sceaux, France - RUDN, Moscow, Russia ####

######## Parameters ######### 
# workspace = storage space defined by the user e.g "C:/Observatories"
# fc1 = first layer to use to create buffers : french cities
# b1  = Radius Buffer in Kilometers for 1rst feature class
# fc2 = second layer to use to create buffers : existing observatories
# b2  = Radius buffer in kilometers for 2nd feature class
# citysize = We want to avoid cities over citysize inhabitants
# coef1 = coefficient in the weighted sum for Crit1
# coef2 = coefficient in the weighted sum for Crit2
# coef3 = coefficient in the weighted sum for Crit3
# percentage = percentage of best pixels of the weithed sum layer that the user wants to keep

def Find_Observatories(workspace,fc1,b1,fc2,b2,citysize,coef1,coef2,coef3,percentage):
    
        ######## Initialization ######### 
        import arcpy
        arcpy.env.workspace = workspace
        arcpy.env.overwriteOutput = True

        intermediate_layers=["fc1_buffer","fc2_buffer","Buffers_Union","Buffers_Dissolved",\
                             "Lum_Vector","Crit1VctEra","Crit1Rst","Crit1NormInv","Crit1Norm",\
                            "RelcassAlt_Vct","Crit2VctEra","Crit2Rst","Crit2Norm",\
                            "Clouds_Vector","Crit3VctEra","Crit3Rst","Crit3Norm",\
                            "arithmeticlayer","Bestpixels","Finalcities","BestpixelsVct","FinalResult"]
                             
        for intermediate_layer in intermediate_layers:
            if arcpy.Exists(intermediate_layer):
                arcpy.Delete_management(intermediate_layer)
                
        ######## Verification #########     
        
        if percentage > 100 or percentage <0 :
            print("The percentage must be between 0 and 100")
        
                
        ######## Buffers layers #########         
                
        #Creation of 2 buffers analysis around the cities over 50k inhabitant 
        #and existing astronomical observatories
        print("Creating buffer around cities with more than",citysize,"inhabitants...","fc1:",fc1)
        outselection = arcpy.SelectLayerByAttribute_management(fc1,'NEW SELECTION', "PTOT >" + str(citysize)) 
        arcpy.Buffer_analysis(outselection, workspace +"/French_cities" + "/"+ "fc1_buffer.shp",b1)
        arcpy.Buffer_analysis(fc2, workspace + "/Observatories" +"/"+ "fc2_buffer.shp",b2)
        print("First feature class: ",fc1,"with ",b1,"buffer",\
              "\nSecond feature class: ",fc2, "with ",b2,"buffer")
        
        #Union and Dissolve of the 2 buffers analysis
        arcpy.Union_analysis([workspace +"/French_cities" + "/"+"fc1_buffer.shp",workspace + "/Observatories" +"/"+"fc2_buffer.shp"],"Buffers_Union")
        arcpy.Dissolve_management("Buffers_Union.shp","Buffers_Dissolved")
        
        
        ######## First Criteria : Luminous Pollution ########
        
        #Conversion of the vector into a Raster 
        #to be able to perfom Erase analysis with the Buffer Union layer
        #And finnaly convert it again into a Raster
        #arcpy.RasterToPolygon_conversion("Lum_in_France.tif", workspace + "/" + "Lum_Vector","SIMPLIFY","Value")
        arcpy.Erase_analysis(workspace + "/Luminous_Pollution" + "/" + "Lum_Vector.shp","Buffers_Dissolved.shp","Crit1VctEra")
        arcpy.FeatureToRaster_conversion("Crit1VctEra.shp","gridcode", workspace + "/Luminous_Pollution"+ "/" + "Crit1Rst",0.01)

        #Normalization of the layer into a 0-100 range
        luminouslayer = arcpy.Raster(workspace + "/Luminous_Pollution" + "/" + "Crit1Rst")
        luminousNormalized = (luminouslayer - luminouslayer.minimum) / (luminouslayer.maximum - luminouslayer.minimum) *100
        luminousNormalized.save(workspace + "/Luminous_Pollution" + "/" + "Crit1NormInv.tif")
        
        #Inversion of the layer so that values close to 100 represent the most wanted areas
        luminousInv = (luminousNormalized - luminousNormalized.maximum)* -1
        luminousInv.save(workspace + "/Luminous_Pollution" + "/" + "Crit1Norm.tif")
        
        
        ######## Second Criteria : Altitude ########
        
        #ReClassification of the layer to reduce the calculation time
        #Conversion of the vector into a Raster 
        #Erase analysis with the Buffer Union layer
        #And finnaly convert it again into a Raster
        #outClassifyAlt= arcpy.sa.Reclassify("Altitude_in_France.crf", "Value", \
                        #arcpy.sa.RemapRange([[0,225,1],[225,563,2],[563,1070,3],[1070,1821,4],[1821,4788,5]]))
        #outClassifyAlt.save(workspace + "/" + "Crit2Class.tif")
        #arcpy.RasterToPolygon_conversion("Crit2Class.tif", workspace + "/" + "RelcassAlt_Vct","SIMPLIFY","Value")
        arcpy.Erase_analysis(workspace +"/Altitude" + "/"+ "RelcassAlt_Vct.shp","Buffers_Dissolved.shp","Crit2VctEra")
        arcpy.FeatureToRaster_conversion("Crit2VctEra.shp","gridcode", workspace + "/Altitude" +"/" + "Crit2Rst",0.01)
        
        #Normalization of the layer into a 0-100 range
        altitudelayer = arcpy.Raster(workspace + "/Altitude" +"/" + "Crit2Rst")
        altitudeNormalized = (altitudelayer - altitudelayer.minimum) / (altitudelayer.maximum-altitudelayer.minimum) *100
        altitudeNormalized.save(workspace + "/Altitude" +"/" + "Crit2Norm.tif")
        
        
        ######## Third Criteria : Cloudiness ########
        
        #Conversion of the vector into a Raster 
        #Erase analysis with the Buffer Union layer
        #And finnaly convert it again into a Raster
        #arcpy.RasterToPolygon_conversion("Clouds_in_France",workspace + "/" + "Clouds_Vector","SIMPLIFY","Value")
        arcpy.Erase_analysis(workspace + "/Cloudiness" +"/"+ "Clouds_Vector.shp","Buffers_Dissolved.shp","Crit3VctEra")
        arcpy.FeatureToRaster_conversion("Crit3VctEra.shp","gridcode",workspace +"/Cloudiness" + "/" + "Crit3Rst",0.01)
        
        #Normalization of the layer into a 0-100 range
        cloudslayer = arcpy.Raster(workspace +"/Cloudiness" + "/" + "Crit3Rst")
        cloudsNormalized = (cloudslayer - cloudslayer.minimum) / (cloudslayer.maximum - cloudslayer.minimum) *100
        cloudsNormalized.save(workspace + "/Cloudiness" +"/" + "Crit3Norm.tif")

        
        ######## Arithmeric Layer : weighted sum ########
        Crit1Norm = arcpy.Raster(workspace + "/Luminous_Pollution" + "/" + "Crit1Norm.tif")
        Crit2Norm = arcpy.Raster(workspace + "/Altitude" +"/" + "Crit2Norm.tif")
        Crit3Norm = arcpy.Raster(workspace + "/Cloudiness" +"/" + "Crit3Norm.tif")
        arithmeticlayer = coef1 * Crit1Norm + coef2 * Crit2Norm + coef3 * Crit3Norm
        print(type(arithmeticlayer))
        arithmeticlayer.save(workspace + "/Results" +"/" + "arithmeticlayer.tif")
        print("Coefficients for weighted sum: ",\
              "\nCoeffient 1 :",coef1,\
              "\nCoeffient 2 :",coef2,\
              "\nCoeffient 3 :",coef3)
        
        ######## Final Results ########
        
        #Definition of the percentage of best pixels the user want to keep
        #Then finding the minumum value of the pixels that the user want to keep
        condition = (arithmeticlayer.maximum - arithmeticlayer.minimum ) / (100/percentage)
        treshold = arithmeticlayer.maximum - condition
        print("Percentage of best pixels kept: ", percentage,"%")
        
        #arcpy.Delete_management("C:/Observatories/Bestpixels")
        
        #Creation of the new layer of Best pixels
        outcon = arcpy.sa.Con(arithmeticlayer,1,"","Value >" + str(treshold))
        outcon.save(workspace  +"/Results"+"/" + "Bestpixels")
    
        arcpy.Erase_analysis("C:/Observatories/French_cities/frenchville.shp","Buffers_Dissolved.shp",workspace  +"/Results"+"/" +"Finalcities")
        
        #Final results giving a village in output 
        arcpy.RasterToPolygon_conversion(workspace  +"/Results"+"/" +"Bestpixels",workspace  +"/Results"+"/" +"BestpixelsVct.shp","SIMPLIFY","VALUE")
        arcpy.Intersect_analysis([workspace  +"/Results"+"/" +"BestpixelsVct.shp",workspace  +"/Results"+"/" +"Finalcities.shp"],workspace  +"/Results"+"/" +"FinalResult.shp")
        
        layerFields = ["*"]
        nbr_results = arcpy.GetCount_management(workspace + "/Results"+"/" + "FinalResult.shp")
        print("Nbr de resultat: ", nbr_results)
        with arcpy.da.SearchCursor(workspace + "/Results"+ "/" + "FinalResult.shp", layerFields) as cursor:
            for row in cursor:
                print("Cities: \n","Name :",row[6],",", "GPS Coordinates: ",\
                      "( latitude:",row[11],"longitude:",row[12],")","\n")

# %%
##EXAMPLE : 
#Find_Observatories("C:/Observatories","C:/Observatories/French_cities/frenchville.shp",\
#                   "50 Kilometers","C:/Observatories/Observatories/Observatories.shp","40 Kilometers",\
#                   50000,3,1,2,20)
# Out:
# Creating buffer around cities with more than 50000 inhabitants... fc1: C:/Observatories/French_cities/frenchville.shp
# First feature class:  C:/Observatories/French_cities/frenchville.shp with  50 Kilometers buffer
# Second feature class:  C:/Observatories/Observatories/Observatories.shp with  40 Kilometers buffer
# <class 'arcpy.sa.Raster.Raster'>
# Coefficients for weighted sum:
# Coeffient 1 : 3
# Coeffient 2 : 1
# Coeffient 3 : 2
# Percentage of best pixels kept:  20 %
# Nbr de resultat:  365
# Cities:
#  Name :  Bilia , GPS Coordinates:  ( latitude: 41.616667 longitude: 8.916667 )
#
# Cities:
#  Name :  Carbini , GPS Coordinates:  ( latitude: 41.666667 longitude: 9.133333 )
#
# Cities:
#  Name :  Zerubia , GPS Coordinates:  ( latitude: 41.75 longitude: 9.066667 )
#
# Cities:
#  Name :  Quenza , GPS Coordinates:  ( latitude: 41.766667 longitude: 9.133333 )
#
# Cities:
#  Name :  Olivese , GPS Coordinates:  ( latitude: 41.833333 longitude: 9.05 )
#
# Cities:
#  Name :  Ucciani , GPS Coordinates:  ( latitude: 42.033333 longitude: 8.983333 )
#
# Cities:
#  Name :  Canavaggia , GPS Coordinates:  ( latitude: 42.05 longitude: 9.266667 )
#
# Cities:
#  Name :  Lopigna , GPS Coordinates:  ( latitude: 42.1 longitude: 8.833333 )
#
# Cities:
#  Name :  Ghisoni , GPS Coordinates:  ( latitude: 42.1 longitude: 9.216667 )
#
# Cities:
#  Name :  Tattone , GPS Coordinates:  ( latitude: 42.15 longitude: 9.15 )
#
# Cities:
#  Name :  Pietroso , GPS Coordinates:  ( latitude: 42.15 longitude: 9.266667 )
#
# Cities:
#  Name :  Guagno , GPS Coordinates:  ( latitude: 42.166667 longitude: 8.933333 )
#
# Cities:
#  Name :  Vivario , GPS Coordinates:  ( latitude: 42.166667 longitude: 9.166667 )
#
# Cities:
#  Name :  Muracciole , GPS Coordinates:  ( latitude: 42.166667 longitude: 9.183333 )
#
# Cities:
#  Name :  Vezzani , GPS Coordinates:  ( latitude: 42.166667 longitude: 9.25 )
#
# Cities:
#  Name :  Antisanti , GPS Coordinates:  ( latitude: 42.166667 longitude: 9.35 )
#
# Cities:
#  Name :  Rospigliani , GPS Coordinates:  ( latitude: 42.183333 longitude: 9.216667 )
#
# Cities:
#  Name :  Soccia , GPS Coordinates:  ( latitude: 42.2 longitude: 8.9 )
#
# Cities:
#  Name :  Noceta , GPS Coordinates:  ( latitude: 42.2 longitude: 9.2 )
#
# Cities:
#  Name :  Giuncaggio , GPS Coordinates:  ( latitude: 42.216667 longitude: 9.366667 )
#
# Cities:
#  Name :  Piedicorte-di-Gaggio , GPS Coordinates:  ( latitude: 42.233333 longitude: 9.333333 )
#
# Cities:
#  Name :  Pietraserena , GPS Coordinates:  ( latitude: 42.233333 longitude: 9.35 )
#
# Cities:
#  Name :  Focicchia , GPS Coordinates:  ( latitude: 42.25 longitude: 9.3 )
#
# Cities:
#  Name :  Linguizzetta , GPS Coordinates:  ( latitude: 42.25 longitude: 9.466667 )
#
# Cities:
#  Name :  Erbajolo , GPS Coordinates:  ( latitude: 42.266667 longitude: 9.283333 )
#
# Cities:
#  Name :  Zuani , GPS Coordinates:  ( latitude: 42.266667 longitude: 9.35 )
#
# Cities:
#  Name :  Favalello , GPS Coordinates:  ( latitude: 42.283333 longitude: 9.266667 )
#
# Cities:
#  Name :  Pianello , GPS Coordinates:  ( latitude: 42.283333 longitude: 9.35 )
#
# Cities:
#  Name :  Castellare-di-Mercurio , GPS Coordinates:  ( latitude: 42.3 longitude: 9.25 )
#
# Cities:
#  Name :  Alando , GPS Coordinates:  ( latitude: 42.3 longitude: 9.283333 )
#
# Cities:
#  Name :  Novale , GPS Coordinates:  ( latitude: 42.3 longitude: 9.416667 )
#
# Cities:
#  Name :  Santa-Lucia-di-Mercurio , GPS Coordinates:  ( latitude: 42.316667 longitude: 9.216667 )
#
# Cities:
#  Name :  Sermano , GPS Coordinates:  ( latitude: 42.316667 longitude: 9.266667 )
#
# Cities:
#  Name :  Bustanico , GPS Coordinates:  ( latitude: 42.316667 longitude: 9.3 )
#
# Cities:
#  Name :  Perelli , GPS Coordinates:  ( latitude: 42.316667 longitude: 9.366667 )
#
# Cities:
#  Name :  Lozzi , GPS Coordinates:  ( latitude: 42.35 longitude: 9 )
#
# Cities:
#  Name :  Santa-Reparata-di-Moriani , GPS Coordinates:  ( latitude: 42.35 longitude: 9.433333 )
#
# Cities:
#  Name :  Rusio , GPS Coordinates:  ( latitude: 42.366667 longitude: 9.25 )
#
# Cities:
#  Name :  San-Giovanni-di-Moriani , GPS Coordinates:  ( latitude: 42.366667 longitude: 9.466667 )
#
# Cities:
#  Name :  Aiti , GPS Coordinates:  ( latitude: 42.4 longitude: 9.233333 )
#
# Cities:
#  Name :  San-Damiano , GPS Coordinates:  ( latitude: 42.4 longitude: 9.416667 )
#
# Cities:
#  Name :  Popolasca , GPS Coordinates:  ( latitude: 42.433333 longitude: 9.133333 )
#
# Cities:
#  Name :  Piano , GPS Coordinates:  ( latitude: 42.45 longitude: 9.383333 )
#
# Cities:
#  Name :  Silvareccio , GPS Coordinates:  ( latitude: 42.45 longitude: 9.4 )
#
# Cities:
#  Name :  Moltifao , GPS Coordinates:  ( latitude: 42.466667 longitude: 9.116667 )
#
# Cities:
#  Name :  Pietralba , GPS Coordinates:  ( latitude: 42.533333 longitude: 9.183333 )
#
# Cities:
#  Name :  Novella , GPS Coordinates:  ( latitude: 42.566667 longitude: 9.116667 )
#
# Cities:
#  Name :  Palasca , GPS Coordinates:  ( latitude: 42.583333 longitude: 9.05 )
#
# Cities:
#  Name :  Sansa , GPS Coordinates:  ( latitude: 42.6 longitude: 2.166667 )
#
# Cities:
#  Name :  Urtaca , GPS Coordinates:  ( latitude: 42.6 longitude: 9.166667 )
#
# Cities:
#  Name :  La Fajolle , GPS Coordinates:  ( latitude: 42.766667 longitude: 1.966667 )
#
# Cities:
#  Name :  Campagna-de-Sault , GPS Coordinates:  ( latitude: 42.766667 longitude: 2.05 )
#
# Cities:
#  Name :  MŽrial , GPS Coordinates:  ( latitude: 42.783333 longitude: 1.983333 )
#
# Cities:
#  Name :  Mayrgne , GPS Coordinates:  ( latitude: 42.833333 longitude: 0.55 )
#
# Cities:
#  Name :  Saint-Paul-d'Oueil , GPS Coordinates:  ( latitude: 42.833333 longitude: 0.55 )
#
# Cities:
#  Name :  Cirs , GPS Coordinates:  ( latitude: 42.85 longitude: 0.516667 )
#
# Cities:
#  Name :  Bourg-d'Oueil , GPS Coordinates:  ( latitude: 42.866667 longitude: 0.5 )
#
# Cities:
#  Name : Bareilles , GPS Coordinates:  ( latitude: 42.9 longitude: 0.433333 )
#
# Cities:
#  Name :  NŽbias , GPS Coordinates:  ( latitude: 42.9 longitude: 2.116667 )
#
# Cities:
#  Name :  Portet-d'Aspet , GPS Coordinates:  ( latitude: 42.933333 longitude: 0.866667 )
#
# Cities:
#  Name :  Peyrolles , GPS Coordinates:  ( latitude: 42.966667 longitude: 2.316667 )
#
# Cities:
#  Name :  Valmigre , GPS Coordinates:  ( latitude: 42.983333 longitude: 2.366667 )
#
# Cities:
#  Name :  Missgre , GPS Coordinates:  ( latitude: 43 longitude: 2.366667 )
#
# Cities:
#  Name :  Villardebelle , GPS Coordinates:  ( latitude: 43.016667 longitude: 2.4 )
#
# Cities:
#  Name :  Lignairolles , GPS Coordinates:  ( latitude: 43.1 longitude: 1.983333 )
#
# Cities:
#  Name :  Orsans , GPS Coordinates:  ( latitude: 43.15 longitude: 1.966667 )
#
# Cities:
#  Name :  La Courtte , GPS Coordinates:  ( latitude: 43.15 longitude: 2.033333 )
#
# Cities:
#  Name :  Ribouisse , GPS Coordinates:  ( latitude: 43.183333 longitude: 1.916667 )
#
# Cities:
#  Name :  Fonters-du-Razs , GPS Coordinates:  ( latitude: 43.233333 longitude: 1.933333 )
#
# Cities:
#  Name :  Montesquieu-Guittaut , GPS Coordinates:  ( latitude: 43.333333 longitude: 0.766667 )
#
# Cities:
#  Name :  NŽnigan , GPS Coordinates:  ( latitude: 43.35 longitude: 0.7 )
#
# Cities:
#  Name :  Labastide-Esparbairenque , GPS Coordinates:  ( latitude: 43.383333 longitude: 2.416667 )
#
# Cities:
#  Name :  Pradelles-Cabards , GPS Coordinates:  ( latitude: 43.4 longitude: 2.45 )
#
# Cities:
#  Name :  Arfons , GPS Coordinates:  ( latitude: 43.433333 longitude: 2.166667 )
#
# Cities:
#  Name :  Laprade , GPS Coordinates:  ( latitude: 43.433333 longitude: 2.266667 )
#
# Cities:
#  Name :  Moncorneil-Grazan , GPS Coordinates:  ( latitude: 43.45 longitude: 0.666667 )
#
# Cities:
#  Name :  Sabaillan , GPS Coordinates:  ( latitude: 43.45 longitude: 0.816667 )
#
# Cities:
#  Name :  Tachoires , GPS Coordinates:  ( latitude: 43.466667 longitude: 0.666667 )
#
# Cities:
#  Name :  Traversres , GPS Coordinates:  ( latitude: 43.533333 longitude: 0.65 )
#
# Cities:
#  Name :  Murasson , GPS Coordinates:  ( latitude: 43.766667 longitude: 2.766667 )
#
# Cities:
#  Name :  Tauriac-de-Camars , GPS Coordinates:  ( latitude: 43.783333 longitude: 3.033333 )
#
# Cities:
#  Name :  Mounes-Prohencoux , GPS Coordinates:  ( latitude: 43.8 longitude: 2.783333 )
#
# Cities:
#  Name :  Cenomes , GPS Coordinates:  ( latitude: 43.8 longitude: 3.016667 )
#
# Cities:
#  Name :  Gissac , GPS Coordinates:  ( latitude: 43.85 longitude: 2.933333 )
#
# Cities:
#  Name :  Marnhagues-et-Latour , GPS Coordinates:  ( latitude: 43.883333 longitude: 3.05 )
#
# Cities:
#  Name :  Les Costes-Gozon , GPS Coordinates:  ( latitude: 44.016667 longitude: 2.8 )
#
# Cities:
#  Name :  Saint-Victor-et-Melvieu , GPS Coordinates:  ( latitude: 44.05 longitude: 2.833333 )
#
# Cities:
#  Name :  Saint-Martin-d'Entraunes , GPS Coordinates:  ( latitude: 44.133333 longitude: 6.766667 )
#
# Cities:
#  Name :  Ch‰teauneuf-d'Entraunes , GPS Coordinates:  ( latitude: 44.133333 longitude: 6.833333 )
#
# Cities:
#  Name :  Entraunes , GPS Coordinates:  ( latitude: 44.183333 longitude: 6.75 )
#
# Cities:
#  Name :  Isola , GPS Coordinates:  ( latitude: 44.183333 longitude: 7.05 )
#
# Cities:
#  Name :  MŽlan , GPS Coordinates:  ( latitude: 44.2 longitude: 6.133333 )
#
# Cities:
#  Name :  Authon , GPS Coordinates:  ( latitude: 44.233333 longitude: 6.133333 )
#
# Cities:
#  Name :  Estng , GPS Coordinates:  ( latitude: 44.233333 longitude: 6.75 )
#
# Cities:
#  Name :  Saint-Geniez , GPS Coordinates:  ( latitude: 44.25 longitude: 6.05 )
#
# Cities:
#  Name :  Mariaud , GPS Coordinates:  ( latitude: 44.25 longitude: 6.433333 )
# Cities:
#  Name :  Ch‰teaufort , GPS Coordinates:  ( latitude: 44.266667 longitude: 6.016667 )
#
# Cities:
#  Name :  Valavoire , GPS Coordinates:  ( latitude: 44.266667 longitude: 6.083333 )
#
# Cities:
#  Name :  Barles , GPS Coordinates:  ( latitude: 44.266667 longitude: 6.266667 )
#
# Cities:
#  Name :  Verdaches , GPS Coordinates:  ( latitude: 44.266667 longitude: 6.333333 )
#
# Cities:
#  Name :  Le Vernet , GPS Coordinates:  ( latitude: 44.283333 longitude: 6.4 )
#
# Cities:
#  Name :  Saint-Dalmas-le-Selvage , GPS Coordinates:  ( latitude: 44.283333 longitude: 6.866667 )
#
# Cities:
#  Name :  Auzet , GPS Coordinates:  ( latitude: 44.3 longitude: 6.3 )
#
# Cities:
#  Name :  Arques , GPS Coordinates:  ( latitude: 44.316667 longitude: 2.8 )
#
# Cities:
#  Name :  Labastide-de-Virac , GPS Coordinates:  ( latitude: 44.35 longitude: 4.416667 )
#
# Cities:
#  Name :  Selonnet , GPS Coordinates:  ( latitude: 44.366667 longitude: 6.3 )
#
# Cities:
#  Name :  La Tieule , GPS Coordinates:  ( latitude: 44.383333 longitude: 3.15 )
#
# Cities:
#  Name :  La Capelle , GPS Coordinates:  ( latitude: 44.4 longitude: 3.3 )
#
# Cities:
#  Name :  Montclar , GPS Coordinates:  ( latitude: 44.4 longitude: 6.333333 )
#
# Cities:
#  Name :  Les Thuiles , GPS Coordinates:  ( latitude: 44.4 longitude: 6.566667 )
#
# Cities:
#  Name :  Saint-Saturnin-de-Lenne , GPS Coordinates:  ( latitude: 44.416667 longitude: 3.016667 )
#
# Cities:
#  Name :  Les Salelles , GPS Coordinates:  ( latitude: 44.416667 longitude: 4.083333 )
#
# Cities:
#  Name :  Gravires , GPS Coordinates:  ( latitude: 44.433333 longitude: 4.083333 )
#
# Cities:
#  Name :  Malarce-sur-la-Thines , GPS Coordinates:  ( latitude: 44.433333 longitude: 4.083333 )
#
# Cities:
#  Name :  Le Lauzet-Ubaye , GPS Coordinates:  ( latitude: 44.433333 longitude: 6.433333 )
#
# Cities:
#  Name :  Lafigre , GPS Coordinates:  ( latitude: 44.45 longitude: 4.033333 )
#
# Cities:
#  Name :  Saint-Vincent-les-Forts , GPS Coordinates:  ( latitude: 44.45 longitude: 6.383333 )
#
# Cities:
#  Name :  Faugres , GPS Coordinates:  ( latitude: 44.475 longitude: 4.133333 )
#
# Cities:
#  Name :  Les Salelles , GPS Coordinates:  ( latitude: 44.483333 longitude: 3.283333 )
#
# Cities:
#  Name :  Le Villard , GPS Coordinates:  ( latitude: 44.483333 longitude: 3.3 )
#
# Cities:
#  Name :  Saint-Jean-de-Pourcharesse , GPS Coordinates:  ( latitude: 44.483333 longitude: 4.1 )
#
# Cities:
#  Name :  Planzolles , GPS Coordinates:  ( latitude: 44.483333 longitude: 4.15 )
#
# Cities:
#  Name :  TrŽlans , GPS Coordinates:  ( latitude: 44.5 longitude: 3.083333 )
#
# Cities:
#  Name :  Saint-AndrŽ-Lachamp , GPS Coordinates:  ( latitude: 44.5 longitude: 4.166667 )
#
# Cities:
#  Name :  Rochecolombe , GPS Coordinates:  ( latitude: 44.5 longitude: 4.45 )
#
# Cities:
#  Name :  Saint-Maurice-d'Ibie , GPS Coordinates:  ( latitude: 44.5 longitude: 4.5 )
#
# Cities:
#  Name :  Les Hermaux , GPS Coordinates:  ( latitude: 44.516667 longitude: 3.116667 )
#
# Cities:
#  Name :  Montselgues , GPS Coordinates:  ( latitude: 44.516667 longitude: 4 )
#
# Cities:
#  Name :  Sablires , GPS Coordinates:  ( latitude: 44.516667 longitude: 4.066667 )
#
# Cities:
#  Name :  Saint-MŽlany , GPS Coordinates:  ( latitude: 44.516667 longitude: 4.116667 )
#
# Cities:
#  Name :  Saint-AndŽol-de-Berg , GPS Coordinates:  ( latitude: 44.516667 longitude: 4.533333 )
#
# Cities:
#  Name :  Prades-d'Aubrac , GPS Coordinates:  ( latitude: 44.533333 longitude: 2.95 )
#
# Cities:
#  Name :  Aurelle-Verlac , GPS Coordinates:  ( latitude: 44.533333 longitude: 2.983333 )
#
# Cities:
#  Name :  Les Salces , GPS Coordinates:  ( latitude: 44.533333 longitude: 3.15 )
#
# Cities:
#  Name :  Gabrias , GPS Coordinates:  ( latitude: 44.55 longitude: 3.383333 )
#
# Cities:
#  Name :  Belvezet , GPS Coordinates:  ( latitude: 44.55 longitude: 3.75 )
#
# Cities:
#  Name :  Saint-FrŽzal-d'Albuges , GPS Coordinates:  ( latitude: 44.55 longitude: 3.766667 )
#
# Cities:
#  Name :  Chasserads , GPS Coordinates:  ( latitude: 44.55 longitude: 3.816667 )
#
# Cities:
#  Name :  Laval-d'Aurelle , GPS Coordinates:  ( latitude: 44.55 longitude: 3.966667 )
#
# Cities:
#  Name :  Dompnac , GPS Coordinates:  ( latitude: 44.55 longitude: 4.1 )
#
# Cities:
#  Name :  Rocles , GPS Coordinates:  ( latitude: 44.55 longitude: 4.216667 )
#
# Cities:
#  Name :  Puy-Sanires , GPS Coordinates:  ( latitude: 44.55 longitude: 6.433333 )
#
# Cities:
#  Name :  Saint-FŽlix-de-Lunel , GPS Coordinates:  ( latitude: 44.566667 longitude: 2.533333 )
#
# Cities:
#  Name :  Le Born , GPS Coordinates:  ( latitude: 44.566667 longitude: 3.55 )
#
# Cities:
#  Name :  Joannas , GPS Coordinates:  ( latitude: 44.566667 longitude: 4.25 )
#
# Cities:
#  Name :  Puy-Saint-Eusbe , GPS Coordinates:  ( latitude: 44.566667 longitude: 6.416667 )
#
# Cities:
#  Name :  Saint-ChŽly-d'Aubrac , GPS Coordinates:  ( latitude: 44.583333 longitude: 2.916667 )
#
# Cities:
#  Name :  Servires , GPS Coordinates:  ( latitude: 44.583333 longitude: 3.416667 )
#
# Cities:
#  Name :  Valgorge , GPS Coordinates:  ( latitude: 44.583333 longitude: 4.116667 )
#
# Cities:
#  Name :  Laboule , GPS Coordinates:  ( latitude: 44.583333 longitude: 4.166667 )
#
# Cities:
#  Name :  Le Cayrol , GPS Coordinates:  ( latitude: 44.6 longitude: 2.8 )
#
# Cities:
#  Name :  Saint-Laurent-de-Muret , GPS Coordinates:  ( latitude: 44.6 longitude: 3.2 )
#
# Cities:
#  Name :  Loubaresse , GPS Coordinates:  ( latitude: 44.6 longitude: 4.05 )
#
# Cities:
#  Name :  Prunet , GPS Coordinates:  ( latitude: 44.6 longitude: 4.266667 )
#
# Cities:
#  Name :  Condom-d'Aubrac , GPS Coordinates:  ( latitude: 44.616667 longitude: 2.866667 )
#
# Cities:
#  Name :  Aubrac , GPS Coordinates:  ( latitude: 44.616667 longitude: 2.983333 )
#
# Cities:
#  Name :  Lachamp , GPS Coordinates:  ( latitude: 44.616667 longitude: 3.383333 )
#
# Cities:
#  Name :  Borne , GPS Coordinates:  ( latitude: 44.616667 longitude: 4.016667 )
#
# Cities:
#  Name :  Sceautres , GPS Coordinates:  ( latitude: 44.616667 longitude: 4.633333 )
#
# Cities:
#  Name :  Florentin-la-Capelle , GPS Coordinates:  ( latitude: 44.633333 longitude: 2.633333 )
#
# Cities:
#  Name :  Ribennes , GPS Coordinates:  ( latitude: 44.633333 longitude: 3.4 )
#
# Cities:
#  Name :  Berzme , GPS Coordinates:  ( latitude: 44.633333 longitude: 4.583333 )
#
# Cities:
#  Name :  Arzenc-de-Randon , GPS Coordinates:  ( latitude: 44.65 longitude: 3.616667 )
#
# Cities:
#  Name :  Cheylard-l'ƒvque , GPS Coordinates:  ( latitude: 44.65 longitude: 3.8 )
#
# Cities:
#  Name :  Saint-Pierre-la-Roche , GPS Coordinates:  ( latitude: 44.65 longitude: 4.616667 )
#
# Cities:
#  Name :  PrinsuŽjols , GPS Coordinates:  ( latitude: 44.666667 longitude: 3.183333 )
#
# Cities:
#  Name :  Pierrefiche , GPS Coordinates:  ( latitude: 44.683333 longitude: 3.733333 )
#
# Cities:
#  Name :  Huparlac , GPS Coordinates:  ( latitude: 44.7 longitude: 2.783333 )
#
# Cities:
#  Name :  La Villedieu , GPS Coordinates:  ( latitude: 44.7 longitude: 3.5 )
#
# Cities:
#  Name :  Saint-Jean-la-Fouillouse , GPS Coordinates:  ( latitude: 44.7 longitude: 3.666667 )
#
# Cities:
#  Name :  Rocles , GPS Coordinates:  ( latitude: 44.7 longitude: 3.783333 )
#
# Cities:
#  Name :  Saint-Alban-en-Montagne , GPS Coordinates:  ( latitude: 44.7 longitude: 3.916667 )
#
# Cities:
#  Name :  Sainte-Colombe , GPS Coordinates:  ( latitude: 44.716667 longitude: 2.016667 )
#
# Cities:
#  Name :  Chastanier , GPS Coordinates:  ( latitude: 44.716667 longitude: 3.75 )
#
# Cities:
#  Name :  La Trinitat , GPS Coordinates:  ( latitude: 44.733333 longitude: 2.95 )
#
# Cities:
#  Name :  Grandvals , GPS Coordinates:  ( latitude: 44.733333 longitude: 3.05 )
#
# Cities:
#  Name :  Saint-Antoine , GPS Coordinates:  ( latitude: 44.75 longitude: 2.333333 )
#
# Cities:
#  Name :  Ladinhac , GPS Coordinates:  ( latitude: 44.75 longitude: 2.516667 )
#
# Cities:
#  Name :  Brion , GPS Coordinates:  ( latitude: 44.75 longitude: 3.083333 )
#
# Cities:
#  Name :  La Fage-Montivernoux , GPS Coordinates:  ( latitude: 44.75 longitude: 3.183333 )
#
# Cities:
#  Name :  VŽronne , GPS Coordinates:  ( latitude: 44.75 longitude: 5.216667 )
#
# Cities:
#  Name :  Saint-MŽdard-Nicourby , GPS Coordinates:  ( latitude: 44.766667 longitude: 2.05 )
#
# Cities:
#  Name :  Lauresses , GPS Coordinates:  ( latitude: 44.766667 longitude: 2.133333 )
#
# Cities:
#  Name :  Leucamp , GPS Coordinates:  ( latitude: 44.766667 longitude: 2.533333 )
#
# Cities:
#  Name :  Vitrac-en-Viadne , GPS Coordinates:  ( latitude: 44.783333 longitude: 2.833333 )
#
# Cities:
#  Name :  Chauchailles , GPS Coordinates:  ( latitude: 44.783333 longitude: 3.1 )
#
# Cities:
#  Name :  Vachres-en-Quint , GPS Coordinates:  ( latitude: 44.783333 longitude: 5.266667 )
#
# Cities:
#  Name :  Vezels-Roussy , GPS Coordinates:  ( latitude: 44.8 longitude: 2.583333 )
#
# Cities:
#  Name :  Jabrun , GPS Coordinates:  ( latitude: 44.8 longitude: 2.966667 )
#
# Cities:
#  Name :  Deux-Verges , GPS Coordinates:  ( latitude: 44.8 longitude: 3.033333 )
#
# Cities:
#  Name :  Laval-Atger , GPS Coordinates:  ( latitude: 44.8 longitude: 3.683333 )
#
# Cities:
#  Name :  Saint-AndŽol , GPS Coordinates:  ( latitude: 44.8 longitude: 5.266667 )
#
# Cities:
#  Name :  Marignac-en-Diois , GPS Coordinates:  ( latitude: 44.8 longitude: 5.333333 )
#
# Cities:
#  Name :  SŽnaillac-Latronquire , GPS Coordinates:  ( latitude: 44.816667 longitude: 2.083333 )
#
# Cities:
#  Name :  Plan-de-Baix , GPS Coordinates:  ( latitude: 44.816667 longitude: 5.166667 )
#
# Cities:
#  Name :  Lacam-d'Ourcet , GPS Coordinates:  ( latitude: 44.85 longitude: 2 )
#
# Cities:
#  Name :  Arzenc-d'Apcher , GPS Coordinates:  ( latitude: 44.85 longitude: 3.116667 )
#
# Cities:
#  Name :  Cros-de-Ronesque , GPS Coordinates:  ( latitude: 44.866667 longitude: 2.616667 )
#
# Cities:
#  Name :  Le Chaffal , GPS Coordinates:  ( latitude: 44.866667 longitude: 5.183333 )
#
# Cities:
#  Name :  Omblze , GPS Coordinates:  ( latitude: 44.866667 longitude: 5.216667 )
#
# Cities:
#  Name :  La Vacherie , GPS Coordinates:  ( latitude: 44.883333 longitude: 5.183333 )
#
# Cities:
#  Name :  Ouides , GPS Coordinates:  ( latitude: 44.9 longitude: 3.733333 )
#
# Cities:
#  Name :  LŽoncel , GPS Coordinates:  ( latitude: 44.9 longitude: 5.2 )
#
# Cities:
#  Name :  Siran , GPS Coordinates:  ( latitude: 44.95 longitude: 2.133333 )
#
# Cities:
#  Name :  Alleuze , GPS Coordinates:  ( latitude: 44.95 longitude: 3.1 )
#
# Cities:
#  Name :  Cussac , GPS Coordinates:  ( latitude: 44.983333 longitude: 2.933333 )
#
# Cities:
#  Name :  Auvers , GPS Coordinates:  ( latitude: 45 longitude: 3.416667 )
#
# Cities:
#  Name :  Sarrazac , GPS Coordinates:  ( latitude: 45.016667 longitude: 1.583333 )
#
# Cities:
#  Name :  Saint-Mathurin-LŽobazel , GPS Coordinates:  ( latitude: 45.016667 longitude: 2.033333 )
#
# Cities:
#  Name :  NŽvache , GPS Coordinates:  ( latitude: 45.01955 longitude: 6.6044 )
#
# Cities:
#  Name :  Jayac , GPS Coordinates:  ( latitude: 45.033333 longitude: 1.333333 )
#
# Cities:
#  Name :  Brivezac , GPS Coordinates:  ( latitude: 45.033333 longitude: 1.85 )
#
# Cities:
#  Name :  Charraix , GPS Coordinates:  ( latitude: 45.033333 longitude: 3.566667 )
#
# Cities:
#  Name :  La Cassagne , GPS Coordinates:  ( latitude: 45.05 longitude: 1.316667 )
#
# Cities:
#  Name :  Arnac , GPS Coordinates:  ( latitude: 45.05 longitude: 2.233333 )
#
# Cities:
#  Name :  Tailhac , GPS Coordinates:  ( latitude: 45.05 longitude: 3.466667 )
#
# Cities:
#  Name :  Saint-Hilaire-Taurieux , GPS Coordinates:  ( latitude: 45.066667 longitude: 1.85 )
#
# Cities:
#  Name :  Saint-Cirgues-de-Malbert , GPS Coordinates:  ( latitude: 45.066667 longitude: 2.383333 )
#
# Cities:
#  Name :  Montchamp , GPS Coordinates:  ( latitude: 45.066667 longitude: 3.2 )
#
# Cities:
#  Name :  Saint-Projet-de-Salers , GPS Coordinates:  ( latitude: 45.083333 longitude: 2.533333 )
#
# Cities:
#  Name :  Chastel , GPS Coordinates:  ( latitude: 45.083333 longitude: 3.316667 )
#
# Cities:
#  Name :  Besse , GPS Coordinates:  ( latitude: 45.1 longitude: 2.35 )
#
# Cities:
#  Name :  Le Fau , GPS Coordinates:  ( latitude: 45.1 longitude: 2.583333 )
#
# Cities:
#  Name :  Rageade , GPS Coordinates:  ( latitude: 45.1 longitude: 3.283333 )
#
# Cities:
#  Name :  Ferrussac , GPS Coordinates:  ( latitude: 45.1 longitude: 3.416667 )
#
# Cities:
#  Name :  Saint-Martial-Entraygues , GPS Coordinates:  ( latitude: 45.116667 longitude: 1.983333 )
#
# Cities:
#  Name :  Loupiac , GPS Coordinates:  ( latitude: 45.116667 longitude: 2.35 )
#
# Cities:
#  Name :  Sainte-Eulalie , GPS Coordinates:  ( latitude: 45.116667 longitude: 2.383333 )
#
# Cities:
#  Name :  Saint-Austremoine , GPS Coordinates:  ( latitude: 45.116667 longitude: 3.383333 )
#
# Cities:
#  Name :  Aubazat , GPS Coordinates:  ( latitude: 45.133333 longitude: 3.45 )
#
# Cities:
#  Name :  Barriac-les-Bosquets , GPS Coordinates:  ( latitude: 45.15 longitude: 2.266667 )
#
# Cities:
#  Name :  Le Falgoux , GPS Coordinates:  ( latitude: 45.15 longitude: 2.616667 )
#
# Cities:
#  Name :  Rilhac-Xaintrie , GPS Coordinates:  ( latitude: 45.166667 longitude: 2.2 )
#
# Cities:
#  Name :  Le Claux , GPS Coordinates:  ( latitude: 45.166667 longitude: 2.716667 )
#
# Cities:
#  Name :  Sainte-Anastasie , GPS Coordinates:  ( latitude: 45.166667 longitude: 2.983333 )
#
# Cities:
#  Name :  Valjouze , GPS Coordinates:  ( latitude: 45.166667 longitude: 3.066667 )
#
# Cities:
#  Name :  Darazac , GPS Coordinates:  ( latitude: 45.183333 longitude: 2.1 )
#
# Cities:
#  Name :  Chaussenac , GPS Coordinates:  ( latitude: 45.183333 longitude: 2.283333 )
#
# Cities:
#  Name :  Saint-Mary-le-Plain , GPS Coordinates:  ( latitude: 45.183333 longitude: 3.166667 )
#
# Cities:
#  Name :  Mazeyrat-Aurouze , GPS Coordinates:  ( latitude: 45.183333 longitude: 3.566667 )
#
# Cities:
#  Name :  Tourniac , GPS Coordinates:  ( latitude: 45.2 longitude: 2.216667 )
#
# Cities:
#  Name :  Le Vaulmier , GPS Coordinates:  ( latitude: 45.2 longitude: 2.566667 )
#
# Cities:
#  Name :  Peyrusse , GPS Coordinates:  ( latitude: 45.2 longitude: 3.033333 )
#
# Cities:
#  Name :  Sainte-Marguerite , GPS Coordinates:  ( latitude: 45.2 longitude: 3.583333 )
#
# Cities:
#  Name :  Charmensac , GPS Coordinates:  ( latitude: 45.216667 longitude: 3.083333 )
#
# Cities:
#  Name :  Bonnac , GPS Coordinates:  ( latitude: 45.216667 longitude: 3.166667 )
#
# Cities:
#  Name :  Josat , GPS Coordinates:  ( latitude: 45.216667 longitude: 3.6 )
#
# Cities:
#  Name :  La Chapelle-Bertin , GPS Coordinates:  ( latitude: 45.216667 longitude: 3.65 )
#
# Cities:
#  Name :  Coubjours , GPS Coordinates:  ( latitude: 45.25 longitude: 1.25 )
#
# Cities:
#  Name :  Clavires , GPS Coordinates:  ( latitude: 45.25 longitude: 2.433333 )
#
# Cities:
#  Name :  MŽallet , GPS Coordinates:  ( latitude: 45.25 longitude: 2.433333 )
#
# Cities:
#  Name :  SŽgur-les-Villas , GPS Coordinates:  ( latitude: 45.25 longitude: 2.833333 )
#
# Cities:
#  Name :  Lubilhac , GPS Coordinates:  ( latitude: 45.25 longitude: 3.25 )
#
# Cities:
#  Name :  SŽgonzac , GPS Coordinates:  ( latitude: 45.266667 longitude: 1.266667 )
#
# Cities:
#  Name :  Saint-Merd-de-Lapleau , GPS Coordinates:  ( latitude: 45.266667 longitude: 2.083333 )
#
# Cities:
#  Name :  Auzers , GPS Coordinates:  ( latitude: 45.266667 longitude: 2.466667 )
#
# Cities:
#  Name :  Pradiers , GPS Coordinates:  ( latitude: 45.266667 longitude: 2.933333 )
#
# Cities:
#  Name :  VŽze , GPS Coordinates:  ( latitude: 45.266667 longitude: 3 )
#
# Cities:
#  Name :  Moldes , GPS Coordinates:  ( latitude: 45.266667 longitude: 3.05 )
#
# Cities:
#  Name :  Auriac-l'ƒglise , GPS Coordinates:  ( latitude: 45.266667 longitude: 3.133333 )
#
# Cities:
#  Name :  Soulages , GPS Coordinates:  ( latitude: 45.283333 longitude: 2.833333 )
#
# Cities:
#  Name :  Laurie , GPS Coordinates:  ( latitude: 45.283333 longitude: 3.1 )
#
# Cities:
#  Name :  Lafage-sur-Sombre , GPS Coordinates:  ( latitude: 45.3 longitude: 2.083333 )
#
# Cities:
#  Name :  Landeyrat , GPS Coordinates:  ( latitude: 45.3 longitude: 2.883333 )
#
# Cities:
#  Name :  Champagnac-la-Noaille , GPS Coordinates:  ( latitude: 45.316667 longitude: 2.016667 )
#
# Cities:
#  Name :  Le Jardin , GPS Coordinates:  ( latitude: 45.316667 longitude: 2.05 )
#
# Cities:
#  Name :  Saint-ƒtienne-sur-Blesle , GPS Coordinates:  ( latitude: 45.316667 longitude: 3.133333 )
#
# Cities:
#  Name :  Saint-Hilaire-Foissac , GPS Coordinates:  ( latitude: 45.333333 longitude: 2.133333 )
#
# Cities:
#  Name :  Veyrires , GPS Coordinates:  ( latitude: 45.333333 longitude: 2.383333 )
#
# Cities:
#  Name :  Autrac , GPS Coordinates:  ( latitude: 45.333333 longitude: 3.133333 )
#
# Cities:
#  Name :  Concze , GPS Coordinates:  ( latitude: 45.35 longitude: 1.35 )
#
# Cities:
#  Name :  Montaignac-Saint-Hippolyte , GPS Coordinates:  ( latitude: 45.35 longitude: 2.016667 )
#
# Cities:
#  Name :  Savignac-LŽdrier , GPS Coordinates:  ( latitude: 45.366667 longitude: 1.216667 )
#
# Cities:
#  Name :  Orliac-de-Bar , GPS Coordinates:  ( latitude: 45.366667 longitude: 1.8 )
#
# Cities:
#  Name :  Saint-Hilaire-Luc , GPS Coordinates:  ( latitude: 45.366667 longitude: 2.2 )
#
# Cities:
#  Name :  Saint-ƒtienne-de-Chomeil , GPS Coordinates:  ( latitude: 45.366667 longitude: 2.6 )
#
# Cities:
#  Name :  Saint-Amandin , GPS Coordinates:  ( latitude: 45.366667 longitude: 2.7 )
#
# Cities:
#  Name :  TrŽmouille , GPS Coordinates:  ( latitude: 45.383333 longitude: 2.683333 )
#
# Cities:
#  Name :  Sarran , GPS Coordinates:  ( latitude: 45.416667 longitude: 1.95 )
#
# Cities:
#  Name :  Marchal , GPS Coordinates:  ( latitude: 45.416667 longitude: 2.633333 )
#
# Cities:
#  Name :  Eyburie , GPS Coordinates:  ( latitude: 45.45 longitude: 1.633333 )
#
# Cities:
#  Name :  Madranges , GPS Coordinates:  ( latitude: 45.483333 longitude: 1.783333 )
#
# Cities:
#  Name :  Grandsaigne , GPS Coordinates:  ( latitude: 45.483333 longitude: 1.933333 )
#
# Cities:
#  Name :  PŽret-Bel-Air , GPS Coordinates:  ( latitude: 45.483333 longitude: 2.05 )
#
# Cities:
#  Name :  Monestier-Port-Dieu , GPS Coordinates:  ( latitude: 45.5 longitude: 2.516667 )
#
# Cities:
#  Name :  Labessette , GPS Coordinates:  ( latitude: 45.5 longitude: 2.533333 )
#
# Cities:
#  Name :  Veix , GPS Coordinates:  ( latitude: 45.516667 longitude: 1.833333 )
#
# Cities:
#  Name :  Lestards , GPS Coordinates:  ( latitude: 45.516667 longitude: 1.866667 )
#
# Cities:
#  Name :  Pradines , GPS Coordinates:  ( latitude: 45.516667 longitude: 1.916667 )
#
# Cities:
#  Name :  Thalamy , GPS Coordinates:  ( latitude: 45.516667 longitude: 2.466667 )
#
# Cities:
#  Name :  Gourdon-Murat , GPS Coordinates:  ( latitude: 45.533333 longitude: 1.9 )
#
# Cities:
#  Name :  Bonnefond , GPS Coordinates:  ( latitude: 45.533333 longitude: 1.983333 )
#
# Cities:
#  Name :  Confolent-Port-Dieu , GPS Coordinates:  ( latitude: 45.55 longitude: 2.516667 )
#
# Cities:
#  Name :  Saint-Hilaire-les-Courbes , GPS Coordinates:  ( latitude: 45.6 longitude: 1.833333 )
#
# Cities:
#  Name :  Viam , GPS Coordinates:  ( latitude: 45.6 longitude: 1.883333 )
#
# Cities:
#  Name :  Saint-Sulpice-les-Bois , GPS Coordinates:  ( latitude: 45.616667 longitude: 2.15 )
#
# Cities:
#  Name :  Saint-Germain-Lavolps , GPS Coordinates:  ( latitude: 45.616667 longitude: 2.216667 )
#
# Cities:
#  Name :  Toy-Viam , GPS Coordinates:  ( latitude: 45.65 longitude: 1.933333 )
#
# Cities:
#  Name :  Couffy-sur-Sarsonne , GPS Coordinates:  ( latitude: 45.666667 longitude: 2.333333 )
#
# Cities:
#  Name :  Lamazire-Haute , GPS Coordinates:  ( latitude: 45.666667 longitude: 2.4 )
#
# Cities:
#  Name :  Rempnat , GPS Coordinates:  ( latitude: 45.7 longitude: 1.883333 )
#
# Cities:
#  Name :  Le Mas-d'Artige , GPS Coordinates:  ( latitude: 45.733333 longitude: 2.183333 )
#
# Cities:
#  Name :  Saint-Oradoux-de-Chirouze , GPS Coordinates:  ( latitude: 45.733333 longitude: 2.333333 )
#
# Cities:
#  Name :  Faux-la-Montagne , GPS Coordinates:  ( latitude: 45.75 longitude: 1.933333 )
#
# Cities:
#  Name :  La Chamba , GPS Coordinates:  ( latitude: 45.75 longitude: 3.766667 )
#
# Cities:
#  Name :  Beissat , GPS Coordinates:  ( latitude: 45.766667 longitude: 2.283333 )
#
# Cities:
#  Name :  Malleret , GPS Coordinates:  ( latitude: 45.766667 longitude: 2.316667 )
#
# Cities:
#  Name :  Pigerolles , GPS Coordinates:  ( latitude: 45.783333 longitude: 2.083333 )
#
# Cities:
#  Name :  Clairavaux , GPS Coordinates:  ( latitude: 45.783333 longitude: 2.166667 )
#
# Cities:
#  Name :  Magnat-l'ƒtrange , GPS Coordinates:  ( latitude: 45.783333 longitude: 2.283333 )
#
# Cities:
#  Name :  Flayat , GPS Coordinates:  ( latitude: 45.783333 longitude: 2.383333 )
#
# Cities:
#  Name :  Saint-Agnant-prs-Crocq , GPS Coordinates:  ( latitude: 45.8 longitude: 2.35 )
#
# Cities:
#  Name :  Gioux , GPS Coordinates:  ( latitude: 45.808333 longitude: 2.125 )
#
# Cities:
#  Name :  Croze , GPS Coordinates:  ( latitude: 45.816667 longitude: 2.158333 )
#
# Cities:
#  Name :  Poussanges , GPS Coordinates:  ( latitude: 45.816667 longitude: 2.216667 )
#
# Cities:
#  Name :  Saint-Georges-Nigremont , GPS Coordinates:  ( latitude: 45.833333 longitude: 2.266667 )
#
# Cities:
#  Name :  Saint-Marc-ˆ-Loubaud , GPS Coordinates:  ( latitude: 45.85 longitude: 2 )
#
# Cities:
#  Name :  La Nouaille , GPS Coordinates:  ( latitude: 45.85 longitude: 2.066667 )
#
# Cities:
#  Name :  Saint-Frion , GPS Coordinates:  ( latitude: 45.866667 longitude: 2.233333 )
#
# Cities:
#  Name :  Pontcharraud , GPS Coordinates:  ( latitude: 45.866667 longitude: 2.283333 )
#
# Cities:
#  Name :  Saint-Maurice-prs-Crocq , GPS Coordinates:  ( latitude: 45.866667 longitude: 2.333333 )
#
# Cities:
#  Name :  Saint-Yrieix-la-Montagne , GPS Coordinates:  ( latitude: 45.883333 longitude: 2.033333 )
#
# Cities:
#  Name :  Saint-Pardoux-d'Arnet , GPS Coordinates:  ( latitude: 45.883333 longitude: 2.333333 )
#
# Cities:
#  Name :  Saint-Oradoux-prs-Crocq , GPS Coordinates:  ( latitude: 45.883333 longitude: 2.4 )
#
# Cities:
#  Name :  Vallires , GPS Coordinates:  ( latitude: 45.9 longitude: 2.033333 )
#
# Cities:
#  Name :  NŽoux , GPS Coordinates:  ( latitude: 45.916667 longitude: 2.25 )
#
# Cities:
#  Name :  Saint-Avit-de-Tardes , GPS Coordinates:  ( latitude: 45.916667 longitude: 2.283333 )
#
# Cities:
#  Name :  La Villetelle , GPS Coordinates:  ( latitude: 45.916667 longitude: 2.35 )
#
# Cities:
#  Name :  Saint-Bard , GPS Coordinates:  ( latitude: 45.916667 longitude: 2.4 )
#
# Cities:
#  Name :  Saint-Pardoux-le-Neuf , GPS Coordinates:  ( latitude: 45.933333 longitude: 2.233333 )
#
# Cities:
#  Name :  Saint-Michel-de-Veisse , GPS Coordinates:  ( latitude: 45.95 longitude: 2.05 )
#
# Cities:
#  Name :  Blessac , GPS Coordinates:  ( latitude: 45.95 longitude: 2.116667 )
#
# Cities:
#  Name :  Mautes , GPS Coordinates:  ( latitude: 45.95 longitude: 2.383333 )
#
# Cities:
#  Name :  Lioux-les-Monges , GPS Coordinates:  ( latitude: 45.95 longitude: 2.45 )
#
# Cities:
#  Name :  Brousse , GPS Coordinates:  ( latitude: 45.966667 longitude: 2.45 )
#
# Cities:
#  Name :  La Pouge , GPS Coordinates:  ( latitude: 45.983333 longitude: 1.95 )
#
# Cities:
#  Name :  Saint-Georges-la-Pouge , GPS Coordinates:  ( latitude: 45.983333 longitude: 1.983333 )
#
# Cities:
#  Name :  Sermur , GPS Coordinates:  ( latitude: 45.983333 longitude: 2.433333 )
#
# Cities:
#  Name :  Le Compas , GPS Coordinates:  ( latitude: 45.983333 longitude: 2.466667 )
#
# Cities:
#  Name :  Saint-Avit-le-Pauvre , GPS Coordinates:  ( latitude: 46 longitude: 2.033333 )
#
# Cities:
#  Name :  Saint-Maixant , GPS Coordinates:  ( latitude: 46 longitude: 2.2 )
#
# Cities:
#  Name :  Fransches , GPS Coordinates:  ( latitude: 46.016667 longitude: 2.033333 )
#
# Cities:
#  Name :  La Rochette , GPS Coordinates:  ( latitude: 46.016667 longitude: 2.1 )
#
# Cities:
#  Name :  Champagnat , GPS Coordinates:  ( latitude: 46.016667 longitude: 2.283333 )
#
# Cities:
#  Name :  Bussire-Nouvelle , GPS Coordinates:  ( latitude: 46.016667 longitude: 2.416667 )
#
# Cities:
#  Name :  Sous-Parsat , GPS Coordinates:  ( latitude: 46.05 longitude: 1.966667 )
#
# Cities:
#  Name :  Mainsat , GPS Coordinates:  ( latitude: 46.05 longitude: 2.383333 )
#
# Cities:
#  Name :  Maisonnisses , GPS Coordinates:  ( latitude: 46.066667 longitude: 1.9 )
#
# Cities:
#  Name :  Arfeuille-Ch‰tain , GPS Coordinates:  ( latitude: 46.066667 longitude: 2.433333 )
#
# Cities:
#  Name :  Saint-Rirand , GPS Coordinates:  ( latitude: 46.066667 longitude: 3.85 )
#
# Cities:
#  Name :  LŽpinas , GPS Coordinates:  ( latitude: 46.083333 longitude: 1.933333 )
#
# Cities:
#  Name :  Savennes , GPS Coordinates:  ( latitude: 46.1 longitude: 1.9 )
#
# Cities:
#  Name :  Peyrabout , GPS Coordinates:  ( latitude: 46.1 longitude: 1.916667 )
#
# Cities:
#  Name :  Saint-Hilaire-la-Plaine , GPS Coordinates:  ( latitude: 46.133333 longitude: 1.983333 )
#
# Cities:
#  Name :  La Celle-sous-Gouzon , GPS Coordinates:  ( latitude: 46.216667 longitude: 2.2 )
#
# Cities:
#  Name :  Rimondeix , GPS Coordinates:  ( latitude: 46.233333 longitude: 2.083333 )
#
# Cities:
#  Name :  Domeyrot , GPS Coordinates:  ( latitude: 46.25 longitude: 2.15 )
#
# Cities:
#  Name :  Saint-Silvain-sous-Toulx , GPS Coordinates:  ( latitude: 46.266667 longitude: 2.166667 )
#
# Cities:
#  Name :  ChŽniers , GPS Coordinates:  ( latitude: 46.35 longitude: 1.833333 )
#
# Cities:
#  Name :  Linard , GPS Coordinates:  ( latitude: 46.366667 longitude: 1.866667 )
#
# Cities:
#  Name :  Leyrat , GPS Coordinates:  ( latitude: 46.366667 longitude: 2.283333 )
#
# Cities:
#  Name :  Mortroux , GPS Coordinates:  ( latitude: 46.4 longitude: 1.916667 )
#
# Cities:
#  Name :  La Fort-du-Temple , GPS Coordinates:  ( latitude: 46.416667 longitude: 1.9 )
#
# Cities:
#  Name :  Fougerolles , GPS Coordinates:  ( latitude: 46.566667 longitude: 1.866667 )
#
# Cities:
#  Name :  Roussillon-en-Morvan , GPS Coordinates:  ( latitude: 47.016667 longitude: 4.1 )
